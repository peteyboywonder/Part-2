# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
wine_df = pd.read_csv('wine.csv')
adult_df = pd.read_csv('adult.csv')

# %%
#Drop Duplicates
wine_df.drop_duplicates(inplace=True)
adult_df.drop_duplicates(inplace=True)
#It does not appear there are dumplicate columns to begin with but for the sake of the assignment.

# %%
#There are no errors in the column data other than the ? and NA values. Those are addressed below.

# %%
#Identify Outliers
def find_outliers_iqr(df):
    for column in df.columns:
        if df[column].dtype != 'object':
            Q1 = df[column].quantile(0.25)
            Q3 = df[column].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
            print(f"Outliers in {column}:", outliers[column].values)

find_outliers_iqr(wine_df)
find_outliers_iqr(adult_df)
# Out:
# Outliers in rating: [4.9 4.9]
# Outliers in num_reviews: [ 1793  1705  1309  1209  1201 12421  5266  4350  3929  3437  3164  3127
#   2935  2826  2765  2480  2419  2177  1892  1199  1141  6803  5938  5545
#   5116  4747  4685  4516  3383  3239  2416  2208  1608  1363  7529  7435
#   7237  5863  5372  5365  4979  4935  4411  3521  3443  3148  3118  2887
#   2858  2712  2710  2551  2530  2228  2220  2207  2144  1910  1864  1520
#   1503  1393  1346  1345  1236  1192  1163  1148  6395  5732  5614  5204
#   5109  4851  4625  4357  4121  3589  3456  3406  3327  3197  3095  3093
#   3089  2546  2418  2370  2228  2133  2080  2053  1993  1949  1948  1943
#   1853  1842  1777  1701  1561  1519  1514  1475  1463  1438  1372  1339
#   1326  1269  1266  1255  1226  1172  1166  1158 10273  9092  7401  7293
#   6521  6345  5152  4994  4767  4457  4266  4023  3997  3829  3660  3620
#   3608  3587  3524  2990  2936  2923  2911  2844  2783  2705  2575  2453
#   2423  2341  2295  2241  2241  2062  2013  1924  1914  1884  1846  1824
#   1797  1749  1743  1645  1638  1615  1544  1528  1525  1493  1471  1465
#   1452  1367  1362  1330  1282  1247  1230  1230  1230  1181  1178 32624
#  16505  9098  8318  7825  7294  6567  6532  6256  6163  5802  5178  4610
#   4127  4091  3825  3788  3725  3648  3545  3453  3354  3225  3224  3101
#   2901  2820  2820  2788  2685  2676  2478  2375  2364  2271  2234  2135
#   2074  2050  2022  1981  1931  1921  1768  1688  1686  1665  1645  1627
#   1611  1573  1355  1343  1341  1337  1319  1308  1301  1267  1209  1164
#   1159  1155]
# Outliers in price: [ 995.          313.5         324.95        692.96        778.06
#   490.          349.          810.89        345.          315.
#   514.85        430.          925.          350.         1620.
#   431.36        824.43        253.          570.51       1280.
#   244.85        719.34        815.          285.86       1410.26
#   813.96        435.75        369.05       1182.77        227.95
#   999.          360.         1190.         1150.          950.
#  1021.21        544.5        1295.          992.2        1289.44
#  1098.9        1094.9         423.5         239.5         381.15
#   584.43        555.2         445.28        362.25        289.
#   325.          234.          500.94        698.9         872.47
#   877.85        827.94        679.72        787.59        480.06
#   290.          795.          371.78009751  873.86        774.4
#   940.          812.63       1500.         1190.          827.94
#   234.9        2087.25       1384.54        820.98       1250.
#  1500.         1715.18        932.3        1372.14        660.96
#  1422.96        340.49        317.63        700.          911.43
#  1150.          698.95       2814.16       1325.          527.26
#  1071.45        299.         1207.6        1252.35        447.95
#   813.96       1410.26       1113.2         654.31        380.
#   292.09        400.85        250.          248.          397.
#   472.5         379.          919.6         680.          438.9
#   249.          252.          232.          276.8        1359.75
#   890.         1198.72       1785.96        391.5        1350.
#  2884.04       1638.95       1595.          519.55        511.9
#   980.          280.          932.3         251.99       1372.14
#   285.          245.75        228.57        319.9         325.
#   345.          895.4        1080.          301.          275.
#  1106.24       1503.         1372.14        241.55        769.9
#   445.          747.17       1746.94        359.9        1260.
#   272.          317.63        399.6         701.05        654.31
#   247.75        945.         2750.          355.95        282.65
#   259.9        1099.28        269.95       1250.          270.44
#   304.54        993.28        249.9        1238.43       1660.
#   299.         3119.08        374.35       2750.          400.
#   229.          239.2         290.7         290.4         312.
#   315.          253.47        298.          228.63        228.9
#   391.65        302.5         415.          317.75        274.95
#   312.6         234.98        374.66        467.65        559.02
#   976.83        266.81        295.          299.28684093 1372.14
#   237.          993.28        270.         1373.66        320.
#   295.          230.          299.          304.          249.8
#   350.03        495.          379.          295.3         465.
#   419.85        340.          940.          385.          241.4
#   235.95        509.25        367.39        280.          245.25
#   239.5         272.          498.614195    425.          259.
#   245.53        265.          249.          260.          348.85
#   654.31        348.85        249.95        260.          532.
#   270.          348.85        243.8         230.          310.        ]
# Outliers in body: [2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2.
#  2. 2. 2. 2. 2. 2. 2. 2. 2. 2.]
# Outliers in acidity: [2. 1. 1. 1. 1. 2. 1. 1. 1. 1. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2.
#  2. 1. 1. 2. 2. 1. 2. 1. 1. 2. 1. 2. 1. 2. 2. 2. 2. 2. 2. 1. 1. 1. 2. 2.
#  2. 2. 2. 1. 2. 2. 2. 2. 2. 2. 2. 1. 2. 2. 2. 2. 2. 1. 2. 1. 2. 2. 2. 1.
#  2. 2. 2. 2. 2. 2. 1. 1. 2. 1. 1. 2. 1. 1. 2. 2. 2. 2. 2. 1. 2. 1. 1. 2.
#  1. 1. 2. 2. 2. 2. 1. 2. 2.]
# Outliers in age: [79 80 90 79 80 81 82 83 81 85 80 90 81 84 81 89 81 83 81 82 80 90 81 83
#  80 90 90 84 80 80 80 81 90 85 90 81 81 80 80 79 81 80 88 87 90 79 83 79
#  80 90 79 79 81 81 90 82 90 87 81 88 80 81 80 81 90 88 89 84 80 80 83 79
#  81 79 90 80 81 90 88 90 90 80 90 81 82 79 81 80 83 90 90 79 81 90 80 90
#  90 79 79 84 90 80 90 81 83 84 81 79 85 82 79 80 90 90 90 84 80 90 90 79
#  84 90 79 90 90 90 82 81 90 84 79 81 82 81 80 90 80 84 82 79 90 84 90 83
#  79 81 80 79 80 79 80 90 90 80 90 90 81 83 82 90 90 81 80 80 90 79 80 82
#  85 80 79 90 81 79 80 79 81 82 88 90 82 88 84 83 79 86 90 90 82 83 81 79
#  90 80 81 79 84 84 79 90 80 81 81 81 90 87 90 80 80 82 90 90 85 82 81]
# Outliers in fnlwgt: [444554 432824 465326 ... 485710 436163 514716]
# Outliers in educational-num: [4 4 3 ... 4 4 4]
# Outliers in capital-gain: [ 7688  3103  6418 ... 15020  1086 15024]
# Outliers in capital-loss: [1721 1876 2415 ... 1669 1977  880]
# Outliers in hours-per-week: [30 30 32 ... 60 11 20]

# %%
# Replace '?' with NaN for numerical columns
def replace_question_marks_with_nan(df):
    for column in df.select_dtypes(include=np.number).columns:
        df[column] = pd.to_numeric(df[column], errors='coerce')

replace_question_marks_with_nan(wine_df)
replace_question_marks_with_nan(adult_df)

# Fill NaN values with the mean of the respective columns
def fill_na_with_mean(df):
    for column in df.select_dtypes(include=np.number).columns:
        df[column].fillna(df[column].mean(), inplace=True)

fill_na_with_mean(wine_df)
fill_na_with_mean(adult_df)

# %%
#The capital gain and loss columns in the adult.csv I left the 0's as it is a possibility that someone did not invest and therefore would have a 0 in those columns.

# %%
#The target for wine.csv is the rating, and for adult.csv it is the classification of their income as the target. Below we will see the visuals for this.

# %%
# Univariate plots for wine.csv
target_wine = 'rating'

for column in wine_df.columns:
    plt.figure(figsize=(10, 5))
    if column == target_wine:
        plt.title(f"{column} (rating)")
    else:
        plt.title(column)

    if wine_df[column].dtype == 'object':
        wine_df[column].value_counts().plot(kind='bar')
    else:
        wine_df[column].plot(kind='hist', bins=20)
    plt.show()

# %%
# Univariate plots for adult.csv
target_adult = 'income'

for column in adult_df.columns:
    plt.figure(figsize=(10, 5))
    if column == target_adult:
        plt.title(f"{column} (income)")
    else:
        plt.title(column)

    if adult_df[column].dtype == 'object':
        adult_df[column].value_counts().plot(kind='bar')
    else:
        adult_df[column].plot(kind='hist', bins=20)
    plt.show()

# %%
#There are no misspellings of data or inconsistencies within the categorical columns and thus cleaning is not needed
